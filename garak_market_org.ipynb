# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in .\venv_crawling\lib\site-packages (4.1.5)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in .\venv_crawling\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in .\venv_crawling\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: trio-websocket~=0.9 in .\venv_crawling\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: attrs>=19.2.0 in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: idna in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in .\venv_crawling\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: wsproto>=0.14 in .\venv_crawling\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: certifi in .\venv_crawling\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2022.5.18)
# Requirement already satisfied: cryptography>=1.3.4 in .\venv_crawling\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (37.0.2)
# Requirement already satisfied: pyOpenSSL>=0.14 in .\venv_crawling\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (22.0.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in .\venv_crawling\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in .\venv_crawling\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in .\venv_crawling\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
# !pip install webdriver_manager
# Out:
# Requirement already satisfied: webdriver_manager in .\venv_crawling\lib\site-packages (3.5.4)
# Requirement already satisfied: requests in .\venv_crawling\lib\site-packages (from webdriver_manager) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in .\venv_crawling\lib\site-packages (from requests->webdriver_manager) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in .\venv_crawling\lib\site-packages (from requests->webdriver_manager) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv_crawling\lib\site-packages (from requests->webdriver_manager) (2022.5.18)
# Requirement already satisfied: idna<4,>=2.5 in .\venv_crawling\lib\site-packages (from requests->webdriver_manager) (3.3)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from webdriver_manager.chrome import ChromeDriverManager

import time

# %%
URL = "https://www.garak.co.kr/price/OZViewer.do?R010680=10&R010690=30&R010700=10"
# URL = "http://www.naver.com"

# %%
chrome_options = webdriver.ChromeOptions()
my_crawling_browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
my_crawling_browser.get(url=URL)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\SKILLSUPPORT\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %%
my_crawling_browser.find_element(By.NAME, "s_date").click()

select_element_s_date_year = my_crawling_browser.find_element(By.CLASS_NAME, "ui-datepicker-year")
select_object_export_option = Select(select_element_s_date_year)
select_object_export_option.select_by_value("2020")

select_element_s_date_year = my_crawling_browser.find_element(By.CLASS_NAME, "ui-datepicker-month")
select_object_export_option = Select(select_element_s_date_year)
select_object_export_option.select_by_visible_text("3월")

select_element_s_date_year = my_crawling_browser.find_elements(By.XPATH, "//td[@data-handler]")
select_element_s_date_year[20].click()

# %%
my_crawling_browser.find_element(By.CLASS_NAME, "oz_ui_layout.btnXLS").click()

# %%
select_element_export_option = my_crawling_browser.find_elements(By.TAG_NAME, "select")[4]
select_object_export_option = Select(select_element_export_option)
select_object_export_option.select_by_visible_text("Microsoft Excel File(*.xlsx)")

# %%
my_crawling_browser.find_elements(By.CLASS_NAME, "ui-button.ui-corner-all.ui-widget")[2].click()

# %%
my_crawling_browser.quit()

# %%
import pandas as pd
import pathlib

# %%
df = pd.read_excel("C:/Users/SKILLSUPPORT/Downloads/noname.xlsx")
# Out:
# c:\data\crawling\venv_crawling\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.shape
# Out:
# (459, 17)

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0        NaN         NaN         NaN        NaN         NaN        NaN
# 1        NaN         NaN         NaN        NaN         NaN        NaN
# 2       [일자]         NaN  2022.05.19        NaN         NaN        NaN
# 3        NaN         NaN         NaN        NaN         NaN        NaN
# 4        NaN         NaN         NaN        NaN         NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         NaN      경매 결과        NaN         NaN         NaN         NaN
# 1         NaN        NaN        NaN         NaN      (가락시장)         NaN
# 2         NaN        NaN        NaN         NaN         NaN         NaN
# 3         NaN        NaN        NaN         NaN         NaN         NaN
# 4         NaN        NaN        NaN         NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         1/9         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
df.tail(50)
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 409                                               한국청과         NaN
# 410                                               한국청과         NaN
# 411                                               한국청과         NaN
# 412                                               한국청과         NaN
# 413                                                 농협         NaN
# 414                                                 농협         NaN
# 415                                               한국청과         NaN
# 416                                               한국청과         NaN
# 417                                               한국청과         NaN
# 418                                                NaN         NaN
# 419  ※ 등급은 산지에서 부여한 것으로 공사에서 당일 경매 결과에 따라 산출하는 등급과 ...         NaN
# 420                                                NaN         NaN
# 421                                                NaN         NaN
# 422                                         서울시농수산식품공사         NaN
# 423                                                NaN         NaN
# 424                                                NaN         NaN
# 425                                                NaN         NaN
# 426                                               [일자]         NaN
# 427                                                NaN         NaN
# 428                                                NaN         NaN
# 429                                                 법인         NaN
# 430                                               한국청과         NaN
# 431                                               한국청과         NaN
# 432                                               한국청과         NaN
# 433                                               한국청과         NaN
# 434                                                 농협         NaN
# 435                                                 농협         NaN
# 436                                                 농협         NaN
# 437                                               중앙청과         NaN
# 438                                               중앙청과         NaN
# 439                                               중앙청과         NaN
# 440                                               중앙청과         NaN
# 441                                               중앙청과         NaN
# 442                                                 농협         NaN
# 443                                                 농협         NaN
# 444                                                 농협         NaN
# 445                                                 농협         NaN
# 446                                                 농협         NaN
# 447                                                 농협         NaN
# 448                                                 농협         NaN
# 449                                                 농협         NaN
# 450                                                 농협         NaN
# 451                                                 농협         NaN
# 452                                                 농협         NaN
# 453                                                 농협         NaN
# 454                                                NaN         NaN
# 455  ※ 등급은 산지에서 부여한 것으로 공사에서 당일 경매 결과에 따라 산출하는 등급과 ...         NaN
# 456                                                NaN         NaN
# 457                                                NaN         NaN
# 458                                         서울시농수산식품공사         NaN
#
#      Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 409         NaN        고구마         NaN      호박고구마         NaN        NaN
# 410         NaN        고구마         NaN      호박고구마         NaN        NaN
# 411         NaN        고구마         NaN      호박고구마         NaN        NaN
# 412         NaN        고구마         NaN      호박고구마         NaN        NaN
# 413         NaN        고구마         NaN      호박고구마         NaN        NaN
# 414         NaN        고구마         NaN      호박고구마         NaN        NaN
# 415         NaN        고구마         NaN      호박고구마         NaN        NaN
# 416         NaN        고구마         NaN      호박고구마         NaN        NaN
# 417         NaN        고구마         NaN      호박고구마         NaN        NaN
# 418         NaN        NaN         NaN        NaN         NaN        NaN
# 419         NaN        NaN         NaN        NaN         NaN        NaN
# 420         NaN        NaN         NaN        NaN         NaN        NaN
# 421         NaN        NaN         NaN        NaN         NaN        NaN
# 422         NaN        NaN         NaN        NaN         NaN        NaN
# 423         NaN        NaN         NaN        NaN         NaN        NaN
# 424         NaN        NaN         NaN        NaN         NaN      경매 결과
# 425         NaN        NaN         NaN        NaN         NaN        NaN
# 426  2022.05.19        NaN         NaN        NaN         NaN        NaN
# 427         NaN        NaN         NaN        NaN         NaN        NaN
# 428         NaN        NaN         NaN        NaN         NaN        NaN
# 429         NaN         품목         NaN         품종         NaN        NaN
# 430         NaN        고구마         NaN      호박고구마         NaN        NaN
# 431         NaN        고구마         NaN      호박고구마         NaN        NaN
# 432         NaN        고구마         NaN      호박고구마         NaN        NaN
# 433         NaN        고구마         NaN      호박고구마         NaN        NaN
# 434         NaN        고구마         NaN      호박고구마         NaN        NaN
# 435         NaN        고구마         NaN      호박고구마         NaN        NaN
# 436         NaN        고구마         NaN      호박고구마         NaN        NaN
# 437         NaN       고구마순         NaN       고구마순         NaN        NaN
# 438         NaN       고구마순         NaN       고구마순         NaN        NaN
# 439         NaN       고구마순         NaN       고구마순         NaN        NaN
# 440         NaN       고구마순         NaN       고구마순         NaN        NaN
# 441         NaN       고구마순         NaN       고구마순         NaN        NaN
# 442         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 443         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 444         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 445         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 446         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 447         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 448         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 449         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 450         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 451         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 452         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 453         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 454         NaN        NaN         NaN        NaN         NaN        NaN
# 455         NaN        NaN         NaN        NaN         NaN        NaN
# 456         NaN        NaN         NaN        NaN         NaN        NaN
# 457         NaN        NaN         NaN        NaN         NaN        NaN
# 458         NaN        NaN         NaN        NaN         NaN        NaN
#
#     Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 409       10kg         NaN         NaN       특(1등)
# 410       10kg         NaN         NaN       특(1등)
# 411       10kg         NaN         NaN       특(1등)
# 412       10kg         NaN         NaN      보통(3등)
# 413       10kg         NaN         NaN       특(1등)
# 414       10kg         NaN         NaN       상(2등)
# 415       10kg         NaN         NaN       특(1등)
# 416       10kg         NaN         NaN       특(1등)
# 417       10kg         NaN         NaN       특(1등)
# 418        NaN         NaN         NaN         NaN
# 419        NaN         NaN         NaN         NaN
# 420        NaN         NaN         NaN         NaN
# 421        NaN         NaN         NaN         NaN
# 422        NaN         NaN         NaN         NaN
# 423        NaN         NaN         NaN         NaN
# 424        NaN         NaN         NaN         NaN
# 425        NaN         NaN      (가락시장)         NaN
# 426        NaN         NaN         NaN         NaN
# 427        NaN         NaN         NaN         NaN
# 428        NaN         NaN         NaN         NaN
# 429         단위         NaN         NaN          등급
# 430       10kg         NaN         NaN       특(1등)
# 431       10kg         NaN         NaN       특(1등)
# 432       10kg         NaN         NaN          4등
# 433       10kg         NaN         NaN       특(1등)
# 434       10kg         NaN         NaN       상(2등)
# 435       10kg         NaN         NaN      보통(3등)
# 436       10kg         NaN         NaN      보통(3등)
# 437        4kg         NaN         NaN       특(1등)
# 438        4kg         NaN         NaN       특(1등)
# 439        4kg         NaN         NaN       특(1등)
# 440        4kg         NaN         NaN       특(1등)
# 441        4kg         NaN         NaN       특(1등)
# 442        4kg         NaN         NaN       특(1등)
# 443        4kg         NaN         NaN       특(1등)
# 444        4kg         NaN         NaN       특(1등)
# 445        4kg         NaN         NaN       특(1등)
# 446        4kg         NaN         NaN       특(1등)
# 447        4kg         NaN         NaN       특(1등)
# 448        4kg         NaN         NaN       특(1등)
# 449        4kg         NaN         NaN       특(1등)
# 450        4kg         NaN         NaN       특(1등)
# 451        4kg         NaN         NaN       특(1등)
# 452        4kg         NaN         NaN       특(1등)
# 453        4kg         NaN         NaN       특(1등)
# 454        NaN         NaN         NaN         NaN
# 455        NaN         NaN         NaN         NaN
# 456        NaN         NaN         NaN         NaN
# 457        NaN         NaN         NaN         NaN
# 458        NaN         NaN         NaN         NaN
#
#                     Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 409                         NaN      17,000      충남 당진시         NaN
# 410                         NaN      14,000      충남 당진시         NaN
# 411                         NaN      14,000      충남 당진시         NaN
# 412                         NaN      12,500      충남 당진시         NaN
# 413                         NaN       8,500      충남 당진시         NaN
# 414                         NaN       9,000      충남 당진시         NaN
# 415                         NaN      26,000      충남 당진시         NaN
# 416                         NaN      24,000      충남 당진시         NaN
# 417                         NaN      23,000      충남 당진시         NaN
# 418                         NaN         NaN         NaN         NaN
# 419                         NaN         NaN         NaN         NaN
# 420                         NaN         NaN         NaN         NaN
# 421                         NaN         NaN         NaN         NaN
# 422  2022년05월19일 목 01시33분57초 오후         NaN         NaN         NaN
# 423                         NaN         NaN         NaN         NaN
# 424                         NaN         NaN         NaN         NaN
# 425                         NaN         NaN         NaN         9/9
# 426                         NaN         NaN         NaN         NaN
# 427                         NaN         NaN         NaN         NaN
# 428                         NaN         NaN         NaN         NaN
# 429                         NaN          경락         출하지         NaN
# 430                         NaN      23,000      충남 당진시         NaN
# 431                         NaN      21,500      충남 당진시         NaN
# 432                         NaN      21,500      충남 당진시         NaN
# 433                         NaN      19,000      충남 당진시         NaN
# 434                         NaN       8,000      충남 태안군         NaN
# 435                         NaN       7,500      충남 태안군         NaN
# 436                         NaN       5,500      충남 태안군         NaN
# 437                         NaN      17,500       광주 남구         NaN
# 438                         NaN      17,500       광주 남구         NaN
# 439                         NaN      17,000       광주 남구         NaN
# 440                         NaN       7,000       광주 서구         NaN
# 441                         NaN       2,000       광주 서구         NaN
# 442                         NaN      18,000       광주 광주         NaN
# 443                         NaN      16,500       광주 남구         NaN
# 444                         NaN      17,000       광주 남구         NaN
# 445                         NaN      17,000       광주 남구         NaN
# 446                         NaN      17,000       광주 남구         NaN
# 447                         NaN      17,000       광주 남구         NaN
# 448                         NaN      17,000       광주 남구         NaN
# 449                         NaN      17,000       광주 남구         NaN
# 450                         NaN      17,000       광주 남구         NaN
# 451                         NaN      17,000       광주 남구         NaN
# 452                         NaN      17,000       광주 남구         NaN
# 453                         NaN      16,500       광주 남구         NaN
# 454                         NaN         NaN         NaN         NaN
# 455                         NaN         NaN         NaN         NaN
# 456                         NaN         NaN         NaN         NaN
# 457                         NaN         NaN         NaN         NaN
# 458  2022년05월19일 목 01시33분57초 오후         NaN         NaN         NaN
#
#     Unnamed: 16
# 409         무농약
# 410         무농약
# 411         무농약
# 412         무농약
# 413          일반
# 414          일반
# 415          일반
# 416          일반
# 417          일반
# 418         NaN
# 419         NaN
# 420         NaN
# 421         NaN
# 422         NaN
# 423         NaN
# 424         NaN
# 425         NaN
# 426         NaN
# 427         NaN
# 428         NaN
# 429       친환경구분
# 430          일반
# 431          일반
# 432          일반
# 433          일반
# 434          일반
# 435          일반
# 436          일반
# 437          일반
# 438          일반
# 439          일반
# 440          일반
# 441          일반
# 442          일반
# 443          일반
# 444          일반
# 445          일반
# 446          일반
# 447          일반
# 448          일반
# 449          일반
# 450          일반
# 451          일반
# 452          일반
# 453          일반
# 454         NaN
# 455         NaN
# 456         NaN
# 457         NaN
# 458         NaN

# %%
df = df[ pd.notnull(df["Unnamed: 0"]) == True ]

# %%
df
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 2                                                 [일자]         NaN
# 5                                                   법인         NaN
# 6                                                 동화청과         NaN
# 7                                                 동화청과         NaN
# 8                                                 동화청과         NaN
# ..                                                 ...         ...
# 451                                                 농협         NaN
# 452                                                 농협         NaN
# 453                                                 농협         NaN
# 455  ※ 등급은 산지에서 부여한 것으로 공사에서 당일 경매 결과에 따라 산출하는 등급과 ...         NaN
# 458                                         서울시농수산식품공사         NaN
#
#      Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 2    2022.05.19        NaN         NaN        NaN         NaN        NaN
# 5           NaN         품목         NaN         품종         NaN        NaN
# 6           NaN        고구마         NaN     고구마(밤)         NaN        NaN
# 7           NaN        고구마         NaN     고구마(밤)         NaN        NaN
# 8           NaN        고구마         NaN     고구마(밤)         NaN        NaN
# ..          ...        ...         ...        ...         ...        ...
# 451         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 452         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 453         NaN   고구마순(줄기)         NaN   고구마순(일반)         NaN        NaN
# 455         NaN        NaN         NaN        NaN         NaN        NaN
# 458         NaN        NaN         NaN        NaN         NaN        NaN
#
#     Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 2          NaN         NaN         NaN         NaN
# 5           단위         NaN         NaN          등급
# 6         10kg         NaN         NaN       특(1등)
# 7         10kg         NaN         NaN       특(1등)
# 8         10kg         NaN         NaN       특(1등)
# ..         ...         ...         ...         ...
# 451        4kg         NaN         NaN       특(1등)
# 452        4kg         NaN         NaN       특(1등)
# 453        4kg         NaN         NaN       특(1등)
# 455        NaN         NaN         NaN         NaN
# 458        NaN         NaN         NaN         NaN
#
#                     Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 2                           NaN         NaN         NaN         NaN
# 5                           NaN          경락         출하지         NaN
# 6                           NaN       3,500      경기 여주시         NaN
# 7                           NaN       8,000      충남 당진시         NaN
# 8                           NaN       4,000      충남 당진시         NaN
# ..                          ...         ...         ...         ...
# 451                         NaN      17,000       광주 남구         NaN
# 452                         NaN      17,000       광주 남구         NaN
# 453                         NaN      16,500       광주 남구         NaN
# 455                         NaN         NaN         NaN         NaN
# 458  2022년05월19일 목 01시33분57초 오후         NaN         NaN         NaN
#
#     Unnamed: 16
# 2           NaN
# 5         친환경구분
# 6            일반
# 7            일반
# 8            일반
# ..          ...
# 451          일반
# 452          일반
# 453          일반
# 455         NaN
# 458         NaN
#
# [388 rows x 17 columns]

# %%
import re

# %%
p = re.compile(r"(\d{4})+[.](\d{2})+[.](\d{2})+")

# %%
p.match("2022.05.7")

# %%
df = df[ df["Unnamed: 0"].apply(lambda x: p.match(x) != None) ]

# %%
df.to_excel("중간결과.xlsx")

# %%
# !pip install psycopg2 sqlalchemy
# Out:
# Requirement already satisfied: psycopg2 in .\venv_crawling\lib\site-packages (2.9.3)
# Requirement already satisfied: sqlalchemy in .\venv_crawling\lib\site-packages (1.4.36)
# Requirement already satisfied: greenlet!=0.4.17 in .\venv_crawling\lib\site-packages (from sqlalchemy) (1.1.2)

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
db = create_engine("postgresql://postgres:ggem1224!@www.gemirawn.io/postgres")
db_connection = db.connect()

# %%
df.to_sql(name="shpark", con=db_connection, if_exists="append", index=False)
# Out:
# 0
